# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
qso1 = np.loadtxt("J004528.26+412944.2.txt")
qso2 = np.loadtxt("J013438.86+305504.7.txt")
qso3 = np.loadtxt("J013508.03+310529.8.txt")

# %%
qso3
# Out:
# array([[3700.     ,    0.     ],
#        [3701.19991,    0.     ],
#        [3702.39982,    0.     ],
#        ...,
#        [9147.5914 ,   61.83393],
#        [9148.79131,   57.63873],
#        [9149.99122,   51.81175]])

# %%
# %matplotlib notebook
plt.plot(qso1[:,0],qso1[:,1],'k-')
plt.xlabel("Wavelength (A)")
plt.ylabel("Relative Flux")
#plt.xlim([5600,6150])
#plt.ylim([1500,7000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Relative Flux')

# %%
plt.plot(qso2[:,0],qso2[:,1],'k-')

# %%
plt.plot(qso3[:,0],qso3[:,1],'k-')
plt.xlabel("Wavelength (A)")
plt.ylabel("Relative Flux")
#plt.xlim([5600,6150])
#plt.ylim([1500,7000])
# Out:
# Text(26.583333333333336, 0.5, 'Relative Flux')
